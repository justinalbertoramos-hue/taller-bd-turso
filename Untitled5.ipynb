# %% [markdown]
# <a href="https://colab.research.google.com/github/justinalbertoramos-hue/taller-bd-turso/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install libsql-experimental

# %%
import libsql_experimental

url = "libsql://ture-yutin.aws-us-west-2.turso.io"
token = "eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9.eyJhIjoicnciLCJpYXQiOjE3ODgxOTA3MjUsImlkIjoiMDFhMDQzZDctMGEwMS03MDNjLTlkOTUtNjQ4NzU4N2IxZGM1Iiwia2lkIjoiZDNsZnFVVVdTRDdBUFZqRC1iampCdEVoazlwNnVHOFZLZ1NvbXNldE51USIsInJpZCI6ImM1NDkzNDVhLTc3YmUtNDI5ZC1hZGUyLTZiZDAwNDY2NDM1YyJ9.uwjmHUs27G8S7HArkp9M04PAVJU9wvgaAZxIlm6JWR-dmX-fcTbchwoqzZUHGvVxo9I1t-4q9cLol6GyLUeHBQ"

conn = libsql_experimental.connect(
    "database.db",
    sync_url=url,
    auth_token=token
)

conn.sync()

print("¡Base de datos conectada correctamente!")
# Out:
# ¡Base de datos conectada correctamente!

# %%
# CREAR / INSERTAR

cursor = conn.cursor()

cursor.execute("""
INSERT INTO usuarios (nombre, correo, edad)
VALUES (?, ?, ?)
""", ("Carlos", "carlos@gmail.com", 22))

conn.commit()
conn.sync()

print("Usuario creado correctamente")
# Out:
# Usuario creado correctamente

# %%
# LEER / CONSULTAR

cursor = conn.cursor()

cursor.execute("SELECT * FROM usuarios")

usuarios = cursor.fetchall()

for usuario in usuarios:
    print(usuario)
# Out:
# (1, 'Juan', 'juan@gmail.com', 20)
# (2, 'María', 'maria@gmail.com', 21)
# (3, 'Pedro', 'pedro@gmail.com', 19)
# (4, 'Juan', 'juan@gmail.com', 20)
# (5, 'María', 'maria@gmail.com', 21)
# (6, 'Pedro', 'pedro@gmail.com', 19)
# (7, 'Carlos', 'carlos@gmail.com', 22)

# %%
# ACTUALIZAR / UPDATE

cursor = conn.cursor()

cursor.execute("""
UPDATE usuarios
SET correo = ?
WHERE id = ?
""", ("carlos_nuevo@gmail.com", 3))

conn.commit()
conn.sync()

print("Usuario actualizado correctamente")
# Out:
# Usuario actualizado correctamente

# %%
# BORRAR / DELETE

cursor = conn.cursor()

cursor.execute("""
DELETE FROM usuarios
WHERE id = ?
""", (3,))

conn.commit()
conn.sync()

print("Usuario eliminado correctamente")
# Out:
# Usuario eliminado correctamente

# %%
# !pip install libsql-experimental
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 10.8 MB/s eta 0:00:00
# ...

# %%
import libsql_experimental

url = "libsql://ture-yutin.aws-us-west-2.turso.io"
token = "eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9.eyJhIjoicnciLCJpYXQiOjE3OTAwMTAxMjgsImlkIjoiMDFhMDQzZDctMGEwMS03MDNjLTlkOTUtNjQ4NzU4N2IxZGM1Iiwia2lkIjoiZDNsZnFVVVdTRDdBUFZqRC1iampCdEVoazlwNnVHOFZLZ1NvbXNldE51USIsInJpZCI6ImM1NDkzNDVhLTc3YmUtNDI5ZC1hZGUyLTZiZDAwNDY2NDM1YyJ9.xC-pMxkrtgSZTH6Qe83xabDmEoUUbB8XmarTB9gYLCEDsEDD4AlrT6tcTGiZVr944jdexa-4zOntc0GcYuRCBg"

conn = libsql_experimental.connect(
    "database.db",
    sync_url=url,
    auth_token=token
)

conn.sync()

print("Conectado correctamente a Turso")
# Out:
# Conectado correctamente a Turso

# %%
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS palabras (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    palabra TEXT NOT NULL
);
""")

conn.commit()
conn.sync()

print("Tabla palabras creada correctamente")
# Out:
# Tabla palabras creada correctamente

# %%
# !pip install libsql-client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 3.7 MB/s eta 0:00:00
# ...

# %%
# Instalación silenciosa de dependencias (evita mostrar el texto de pip)
# !pip install -q libsql-client requests

import libsql_client
import requests

# 1. Credenciales de la base de datos en Turso
TURSO_URL = "https://ture-yutin.aws-us-west-2.turso.io"
TURSO_TOKEN = "eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9.eyJhIjoicnciLCJpYXQiOjE3OTAyMDg2OTgsImlkIjoiMDFhMDQzZDctMGEwMS03MDNjLTlkOTUtNjQ4NzU4N2IxZGM1Iiwia2lkIjoiZDNsZnFVVVdTRDdBUFZqRC1iampCdEVoazlwNnVHOFZLZ1NvbXNldE51USIsInJpZCI6ImM1NDkzNDVhLTc3YmUtNDI5ZC1hZGUyLTZiZDAwNDY2NDM1YyJ9.lrx1ZbsW2O9omO8raiDfJbYvW15sCXDxeFEk5Yf8J1EQCOPPkoFCdM4nT1teDiahOwWr7T5Hvw3c01HTaQLFBw"

# 2. Consulta a la API para obtener la palabra aleatoria en español
url_api = "https://random-word-api.herokuapp.com/word?lang=es"
respuesta = requests.get(url_api)
datos = respuesta.json()

# Extraer la palabra obtenida de la lista
palabra_generada = datos[0]
print(f"Palabra generada por la API: {palabra_generada}")

# 3. Conexión a Turso e inserción de la palabra
client = libsql_client.create_client_sync(url=TURSO_URL, auth_token=TURSO_TOKEN)

try:
    # Verificación de la estructura de la tabla 'palabras'
    client.execute("""
    CREATE TABLE IF NOT EXISTS palabras (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        palabra TEXT NOT NULL
    );
    """)

    # Inserción de la palabra devuelta por la API
    resultado = client.execute(
        "INSERT INTO palabras (palabra) VALUES (?) RETURNING id",
        [palabra_generada]
    )

    id_creado = resultado.rows[0][0]
    print(f"¡Éxito! La palabra '{palabra_generada}' se guardó en Turso con el ID: {id_creado}")

except Exception as e:
    print(f"Error al insertar: {e}")

finally:
    client.close()
# Out:
# Palabra generada por la API: síntesis
# ¡Éxito! La palabra 'síntesis' se guardó en Turso con el ID: 6
